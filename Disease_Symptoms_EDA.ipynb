# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/Disease dataset/Disease_symptom_and_patient_profile_dataset.csv")

# %%
#how does our data look like?
df.sample(5)
# Out:
#               Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 31          Sinusitis    No   Yes     Yes                   No   30    Male
# 200           Tetanus    No    No     Yes                   No   45    Male
# 185   Crohn's Disease   Yes   Yes     Yes                   No   45  Female
# 37   Bipolar Disorder    No    No     Yes                   No   30  Female
# 341       Tonsillitis   Yes   Yes     Yes                   No   70  Female
#
#     Blood Pressure Cholesterol Level Outcome Variable
# 31          Normal            Normal         Negative
# 200         Normal              High         Positive
# 185           High              High         Positive
# 37            High              High         Positive
# 341           High              High         Positive

# %%
#checking data in 1st 5 column and rows
df.head()
# Out:
#        Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 0    Influenza   Yes    No     Yes                  Yes   19  Female
# 1  Common Cold    No   Yes     Yes                   No   25  Female
# 2       Eczema    No   Yes     Yes                   No   25  Female
# 3       Asthma   Yes   Yes      No                  Yes   25    Male
# 4       Asthma   Yes   Yes      No                  Yes   25    Male
#
#   Blood Pressure Cholesterol Level Outcome Variable
# 0            Low            Normal         Positive
# 1         Normal            Normal         Negative
# 2         Normal            Normal         Negative
# 3         Normal            Normal         Positive
# 4         Normal            Normal         Positive

# %%
#checking data types of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349 entries, 0 to 348
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Disease               349 non-null    object
#  1   Fever                 349 non-null    object
#  2   Cough                 349 non-null    object
#  3   Fatigue               349 non-null    object
#  4   Difficulty Breathing  349 non-null    object
#  5   Age                   349 non-null    int64
#  6   Gender                349 non-null    object
#  7   Blood Pressure        349 non-null    object
#  8   Cholesterol Level     349 non-null    object
#  9   Outcome Variable      349 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 27.4+ KB

# %%
#last 5 rows data checking
df.tail()
# Out:
#     Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 344  Stroke   Yes    No     Yes                   No   80  Female
# 345  Stroke   Yes    No     Yes                   No   85    Male
# 346  Stroke   Yes    No     Yes                   No   85    Male
# 347  Stroke   Yes    No     Yes                   No   90  Female
# 348  Stroke   Yes    No     Yes                   No   90  Female
#
#     Blood Pressure Cholesterol Level Outcome Variable
# 344           High              High         Positive
# 345           High              High         Positive
# 346           High              High         Positive
# 347           High              High         Positive
# 348           High              High         Positive

# %%
df.isnull()
# Out:
#      Disease  Fever  Cough  Fatigue  Difficulty Breathing    Age  Gender  \
# 0      False  False  False    False                 False  False   False
# 1      False  False  False    False                 False  False   False
# 2      False  False  False    False                 False  False   False
# 3      False  False  False    False                 False  False   False
# 4      False  False  False    False                 False  False   False
# ..       ...    ...    ...      ...                   ...    ...     ...
# 344    False  False  False    False                 False  False   False
# 345    False  False  False    False                 False  False   False
# 346    False  False  False    False                 False  False   False
# 347    False  False  False    False                 False  False   False
# 348    False  False  False    False                 False  False   False
#
#      Blood Pressure  Cholesterol Level  Outcome Variable
# ...

# %%
#checking for null values
df.isnull().sum()
# Out:
# Disease                 0
# Fever                   0
# Cough                   0
# Fatigue                 0
# Difficulty Breathing    0
# Age                     0
# Gender                  0
# Blood Pressure          0
# Cholesterol Level       0
# Outcome Variable        0
# dtype: int64

# %%
#what is the size of dataset
df.shape
# Out:
# (349, 10)

# %%
#check the number of unique values
df.nunique()
# Out:
# Disease                 116
# Fever                     2
# Cough                     2
# Fatigue                   2
# Difficulty Breathing      2
# Age                      26
# Gender                    2
# Blood Pressure            3
# Cholesterol Level         3
# Outcome Variable          2
# dtype: int64

# %%
sns.catplot(x="Outcome Variable", y="Age", data=df, kind="swarm")

# %% [markdown]
# people have old ages have higher probability of being tested positive for disease which is oultlier for our dataset.

# %%
sns.displot(df["Age"], kde=True)

# %% [markdown]
# there is no major skewness in the dataset with few outliers

# %%
df.groupby('Gender').size().plot(kind='pie', autopct="%.2f")
# Out:
# <Axes: >

# %% [markdown]
# these dataset is quite even equally in distributed based on gender

# %%
sns.catplot(x="Fever", kind="count", data=df, hue="Outcome Variable")

# %% [markdown]
# having a fever is major inndication of positive diagnosis

# %%
sns.catplot(x="Cough", kind="count", data=df, hue="Outcome Variable")

# %% [markdown]
# nothing major can be cough, it is quite common.

# %%
sns.catplot(x="Fatigue", kind="count", data=df, hue="Outcome Variable")

# %%
df.groupby("Cholesterol Level").size().plot(kind="pie", autopct="%.2f")
# Out:
# <Axes: >

# %% [markdown]
# majority of people have high cholestrol level

# %%
#dropping name column
df = df.iloc[:,1:]

# %%
df.tail()
# Out:
#     Fever Cough Fatigue Difficulty Breathing  Age  Gender Blood Pressure  \
# 344   Yes    No     Yes                   No   80  Female           High
# 345   Yes    No     Yes                   No   85    Male           High
# 346   Yes    No     Yes                   No   85    Male           High
# 347   Yes    No     Yes                   No   90  Female           High
# 348   Yes    No     Yes                   No   90  Female           High
#
#     Cholesterol Level Outcome Variable
# 344              High         Positive
# 345              High         Positive
# 346              High         Positive
# 347              High         Positive
# 348              High         Positive

# %% [markdown]
# SYMPTOMS BASE PREDICTIONS
